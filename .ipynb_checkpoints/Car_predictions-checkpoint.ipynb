# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score  # Evaluation

# %%
cars_data = pd.read_csv("Cardetails.csv")
cars_data.head(8)
# Out:
#                             name  year  selling_price  km_driven    fuel  \
# 0         Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1   Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2       Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3      Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4         Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5  Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 6   Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# 7             Maruti 800 DX BSII  2001          45000       5000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# ...

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
cars_data["seller_type"].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
cars_data.drop(columns = ['torque'], inplace = True)

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 762.1+ KB

# %%
cars_data.dropna(inplace=True)

# %%
cars_data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# seats            0
# dtype: int64

# %%
cars_data.duplicated().sum()
# Out:
# np.int64(1189)

# %%
cars_data.shape
# Out:
# (7907, 12)

# %%
# for col in cars_data.columns:
#     print("Unique value of" + col)
#     print(cars_data[col].unique())

# %%
def splitCarName(carName):
    carName = carName.split(' ')[0]
    return carName

cars_data['name'] = cars_data['name'].apply(splitCarName)

# %%
def splitMileage(mileage):
    return mileage.split(' ')[0]
    
cars_data["mileage"] = cars_data["mileage"].apply(splitMileage)

# %%
def splitEngine(engine):
    return engine.split(' ')[0]
    
cars_data["engine"] = c
    ars_data["engine"].apply(splitEngine)

# %%
def splitMax_power(max_power):
    return max_power.split(' ')[0]
    
cars_data["max_power"] = cars_data["max_power"].apply(splitMax_power)

# %%
cars_data.head()
# Out:
#       name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0   Maruti  2014         450000     145500  Diesel  Individual       Manual
# 1    Skoda  2014         370000     120000  Diesel  Individual       Manual
# 2    Honda  2006         158000     140000  Petrol  Individual       Manual
# 3  Hyundai  2010         225000     127000  Diesel  Individual       Manual
# 4   Maruti  2007         130000     120000  Petrol  Individual       Manual
#
#           owner mileage   engine max_power  seats
# 0   First Owner    23.4  1248 CC        74    5.0
# 1  Second Owner   21.14  1498 CC    103.52    5.0
# 2   Third Owner    17.7  1497 CC        78    5.0
# 3   First Owner    23.0  1396 CC        90    5.0
# 4   First Owner    16.1  1298 CC      88.2    5.0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

cars_data['name'] = le.fit_transform(cars_data['name']).astype(float)

# %%
cars_data
# Out:
#       name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0     20.0  2014         450000     145500  Diesel  Individual       Manual
# 1     26.0  2014         370000     120000  Diesel  Individual       Manual
# 2     10.0  2006         158000     140000  Petrol  Individual       Manual
# 3     11.0  2010         225000     127000  Diesel  Individual       Manual
# 4     20.0  2007         130000     120000  Petrol  Individual       Manual
# ...    ...   ...            ...        ...     ...         ...          ...
# 8123  11.0  2013         320000     110000  Petrol  Individual       Manual
# 8124  11.0  2007         135000     119000  Diesel  Individual       Manual
# 8125  20.0  2009         382000     120000  Diesel  Individual       Manual
# 8126  27.0  2013         290000      25000  Diesel  Individual       Manual
# 8127  27.0  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner mileage engine max_power  \
# ...

# %%
le = LabelEncoder()

cars_data['seller_type'] = le.fit_transform(cars_data['seller_type']).astype(float)
cars_data
# Out:
#       name  year  selling_price  km_driven    fuel  seller_type transmission  \
# 0     20.0  2014         450000     145500  Diesel          1.0       Manual
# 1     26.0  2014         370000     120000  Diesel          1.0       Manual
# 2     10.0  2006         158000     140000  Petrol          1.0       Manual
# 3     11.0  2010         225000     127000  Diesel          1.0       Manual
# 4     20.0  2007         130000     120000  Petrol          1.0       Manual
# ...    ...   ...            ...        ...     ...          ...          ...
# 8123  11.0  2013         320000     110000  Petrol          1.0       Manual
# 8124  11.0  2007         135000     119000  Diesel          1.0       Manual
# 8125  20.0  2009         382000     120000  Diesel          1.0       Manual
# 8126  27.0  2013         290000      25000  Diesel          1.0       Manual
# 8127  27.0  2013         290000      25000  Diesel          1.0       Manual
#
# ...

# %%
le = LabelEncoder()

cars_data['selling_price'] = le.fit_transform(cars_data['selling_price']).astype(float)
cars_data
# Out:
#       name  year  selling_price  km_driven    fuel  seller_type transmission  \
# 0     20.0  2014          276.0     145500  Diesel          1.0       Manual
# 1     26.0  2014          223.0     120000  Diesel          1.0       Manual
# 2     10.0  2006           90.0     140000  Petrol          1.0       Manual
# 3     11.0  2010          131.0     127000  Diesel          1.0       Manual
# 4     20.0  2007           70.0     120000  Petrol          1.0       Manual
# ...    ...   ...            ...        ...     ...          ...          ...
# 8123  11.0  2013          193.0     110000  Petrol          1.0       Manual
# 8124  11.0  2007           73.0     119000  Diesel          1.0       Manual
# 8125  20.0  2009          232.0     120000  Diesel          1.0       Manual
# 8126  27.0  2013          172.0      25000  Diesel          1.0       Manual
# 8127  27.0  2013          172.0      25000  Diesel          1.0       Manual
#
# ...

# %%
cars_data['fuel'] = le.fit_transform(cars_data['fuel']).astype(float)
cars_data
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type transmission  \
# 0     20.0  2014          276.0     145500   1.0          1.0       Manual
# 1     26.0  2014          223.0     120000   1.0          1.0       Manual
# 2     10.0  2006           90.0     140000   3.0          1.0       Manual
# 3     11.0  2010          131.0     127000   1.0          1.0       Manual
# 4     20.0  2007           70.0     120000   3.0          1.0       Manual
# ...    ...   ...            ...        ...   ...          ...          ...
# 8123  11.0  2013          193.0     110000   3.0          1.0       Manual
# 8124  11.0  2007           73.0     119000   1.0          1.0       Manual
# 8125  20.0  2009          232.0     120000   1.0          1.0       Manual
# 8126  27.0  2013          172.0      25000   1.0          1.0       Manual
# 8127  27.0  2013          172.0      25000   1.0          1.0       Manual
#
#                      owner mileage   engine max_power  seats
# ...

# %%
# cars_data['torque'] = le.fit_transform(cars_data['torque'])
# cars_data

# %%
cars_data['owner'] = le.fit_transform(cars_data['owner']).astype(float)
cars_data
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     20.0  2014          276.0     145500   1.0          1.0           1.0
# 1     26.0  2014          223.0     120000   1.0          1.0           1.0
# 2     10.0  2006           90.0     140000   3.0          1.0           1.0
# 3     11.0  2010          131.0     127000   1.0          1.0           1.0
# 4     20.0  2007           70.0     120000   3.0          1.0           1.0
# ...    ...   ...            ...        ...   ...          ...           ...
# 8123  11.0  2013          193.0     110000   3.0          1.0           1.0
# 8124  11.0  2007           73.0     119000   1.0          1.0           1.0
# 8125  20.0  2009          232.0     120000   1.0          1.0           1.0
# 8126  27.0  2013          172.0      25000   1.0          1.0           1.0
# 8127  27.0  2013          172.0      25000   1.0          1.0           1.0
#
#       owner mileage   engine max_power  seats
# ...

# %%
cars_data['transmission'] = le.fit_transform(cars_data['transmission']).astype(float)
cars_data['mileage'] = le.fit_transform(cars_data['mileage']).astype(float)
cars_data['engine'] = le.fit_transform(cars_data['engine']).astype(float)
cars_data['max_power'] = le.fit_transform(cars_data['max_power']).astype(float)
cars_data.dtypes
# Out:
# name             float64
# year               int64
# selling_price    float64
# km_driven          int64
# fuel             float64
# seller_type      float64
# transmission     float64
# owner            float64
# mileage          float64
# engine           float64
# max_power        float64
# seats            float64
# dtype: object

# %%
#  creating model

# %%
# Input and Output
input_data = cars_data.drop(columns=['selling_price'])
output_data = cars_data['selling_price']

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2)

# %%
model =LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predict=model.predict(x_test)
print(predict)
import pickle

with open ("model.pkl","wb") as f:
    pickle.dump(model,f)
print("model saved succesfully")
# Out:
# [313.20534341 309.12277354 372.14231503 ... 309.70803413 433.43109495
#  332.4183662 ]
# model saved succesfully

# %%
x_test.head(1)
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 6949  19.0  2013     110000   1.0          1.0           1.0    0.0    125.0
#
#       engine  max_power  seats
# 6949    90.0      205.0    7.0

# %%
input_data_model= pd.DataFrame()

# %%
def get_brand_name(car_name):
    car_name = car_name.split(' ')[0]
    return car_name.strip()

# %%
def clean_data(value):
    value= value.split(' ')[0]
    value = value.strip()
    if value == '':
        value = 0
    return float(value)

# %%
get_brand_name("Maruti Swift Dzire VDI")
# Out:
# 'Maruti'

# %%
cars_data['name']= cars_data['name'].apply(get_brand_name)

# %%
cars_data['name'].unique()
